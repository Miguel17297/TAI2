# %%
import pandas as pd
import matplotlib.pyplot as plt
from io import StringIO

# %%
# Out:
#    ref  a  k          res  ratio
# 0  100  0  1  13677540.04   0.80
# 1  100  0  2  12519514.02   0.92
# 2  100  0  3  11630981.22   0.93
# 3  100  0  4  11424133.80   0.98
# 4  100  0  5  12525222.85   1.10

# %%
data_ref100_a0 = pd.read_csv("../results/lang_ref100a0pt.csv")
data_ref100_a0.head()
x = data_ref100_a0['k']
y = data_ref100_a0['res']

data_ref100_a01 = pd.read_csv("../results/lang_ref100a01pt.csv")

fig, axs = plt.subplots(2,2, figsize=(10,10))
axs[0,0].plot(x, y)
axs[0,0].set_xlabel("K")
axs[0,0].set_ylabel("Number of bits")
axs[0,0].set_title("Alpha : 0")

x = data_ref100_a01['k']
y = data_ref100_a01['res']

axs[1,0].plot(x, y)
axs[1,0].set_xlabel("K")
axs[1,0].set_ylabel("Number of bits")
axs[1,0].set_title("Alpha : 0.1")

ref100_a001 = '''
ref,a,k,res,ratio
100,0.01,1,13772263.23,1.10    
100,0.01,2,13075834.81,0.95    
100,0.01,3, 12979113.11,0.99    
100,0.01,4,13264973.62,1.02    
100,0.01,5,14685222.75,1.11
'''


data_ref100_a001 = pd.read_csv(StringIO(ref100_a001))

x = data_ref100_a001['k']
y = data_ref100_a001['res']
axs[0,1].plot(x, y)
axs[0,1].set_xlabel("K")
axs[0,1].set_ylabel("Number of bits")
axs[0,1].set_title("Alpha : 0.01")

ref100_a1 = '''
ref,a,k,res,ratio
100,1,1,13740122.65,0.93    
100,1,2,12954066.79,0.94    
100,1,3,13128167.95,1.01    
100,1,4,14526271.66,1.11    
100,1,5,17041205.42,1.17   
'''


data_ref100_a1 = pd.read_csv(StringIO(ref100_a1))

x = data_ref100_a1['k']
y = data_ref100_a1['res']
axs[1,1].plot(x, y)
axs[1,1].set_xlabel("K")
axs[1,1].set_ylabel("Number of bits")
axs[1,1].set_title("Alpha : 1")
# Out:
# Text(0.5, 1.0, 'Alpha : 1')

# %%
fig, axs = plt.subplots(2,3, figsize=(16,10))
fig.delaxes(axs[1,2])

ref100_k1 = '''
ref,k,a,res,ratio
100,1,0,13677540.04,0.80    
100,1,0.01,13772263.23,1.01    
100,1,0.1 ,13749886.85,1.00    
100,1,1,13740122.65,1.00 
'''

data_ref100_k1 = pd.read_csv(StringIO(ref100_k1))
x = data_ref100_k1['a']
y = data_ref100_k1['res']

axs[0,0].plot(x, y)
axs[0,0].set_xlabel("Alpha")
axs[0,0].set_ylabel("Number of bits")
axs[0,0].set_title("K : 1")


ref100_k2 = '''
ref,k,a,res,ratio
100,2,0,12519514.02,0.91    
100,2,0.01,13075834.81,1.04    
100,2,0.1 ,12929118.33,0.99    
100,2,1,12954066.79,1.00 
'''

data_ref100_k2 = pd.read_csv(StringIO(ref100_k2))
x = data_ref100_k2['a']
y = data_ref100_k2['res']

axs[0,1].plot(x, y)
axs[0,1].set_xlabel("Alpha")
axs[0,1].set_ylabel("Number of bits")
axs[0,1].set_title("K : 2")

ref100_k4 = '''
ref,k,a,res,ratio
100,4,0,11424133.80,0.87    
100,4,0.01,13264973.62,1.16    
100,4,0.1 ,13099351.51,0.99    
100,4,1,14526271.66,1.11    
'''

data_ref100_k4 = pd.read_csv(StringIO(ref100_k4))
x = data_ref100_k4['a']
y = data_ref100_k4['res']

axs[1,0].plot(x, y)
axs[1,0].set_xlabel("Alpha")
axs[1,0].set_ylabel("Number of bits")
axs[1,0].set_title("K : 4")

data_ref100_k3 = pd.read_csv("../results/lang_ref100k3pt.csv")
x = data_ref100_k3['a']
y = data_ref100_k3['res']

axs[0,2].plot(x, y)
axs[0,2].set_xlabel("Alpha")
axs[0,2].set_ylabel("Number of bits")
axs[0,2].set_title("K : 3")

data_ref100_k5 = pd.read_csv("../results/lang_ref100k5pt.csv")
x = data_ref100_k5['a']
y = data_ref100_k5['res']

axs[1,1].plot(x, y)
axs[1,1].set_xlabel("Alpha")
axs[1,1].set_ylabel("Number of bits")
axs[1,1].set_title("K : 5")
# Out:
# Text(0.5, 1.0, 'K : 5')

# %%
data_k3a01pt = pd.read_csv("../results/lan_k3a01pt.csv")
x = data_k3a01pt['ref']
y = data_k3a01pt['res']

data_k3a01pt.head()
# Out:
#    a    k  ref          res  ratio
# 0  3  0.1   25  13494033.38   1.04
# 1  3  0.1   50  12995148.35   0.96
# 2  3  0.1  100  12688446.53   0.98

# %%
plt.plot(x, y)
plt.xlabel("Reference size (%)")
plt.ylabel("Number of bits")
plt.title("Number bits variation in order Reference text Size for K 3 Alpha 0.1")
# Out:
# Text(0.5, 1.0, 'Number bits variation in order Reference text Size for K 3 Alpha 0.1')

# %%
data_k3a0pt = pd.read_csv("../results/lang_k3a0.csv")
x = data_k3a01pt['ref']
y = data_k3a01pt['res']

plt.plot(x, y)
plt.xlabel("Reference size (%)")
plt.ylabel("Number of bits")
plt.title("Number bits variation in order Reference text Size for K 3 Alpha 0")
# Out:
# Text(0.5, 1.0, 'Number bits variation in order Reference text Size for K 3 Alpha 0')

# %%
data_k3a0pt.head()
# Out:
#    a  k  ref          res  ratio
# 0  3  0   25  12047893.12   0.93
# 1  3  0   50  11767492.47   0.98
# 2  3  0  100  11630981.22   0.99
